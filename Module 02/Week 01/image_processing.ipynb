# %% [markdown]
# *Import libraries*

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# *Download image*

# %%
# !gdown 1i9dqan21DjQoG5Q_VEvm0LrVwAlXD0vB

# %% [markdown]
# *Read image*

# %%
img = mpimg.imread('C:\\Users\\MinhKhanh\\Documents\\workspace\\AIO-2024\\AIO-Exercise\\Module 02\\Week 01\\source\\dog.jpeg')

# %% [markdown]
# *Set definition*

# %%
def color2grayscale(vector):
    return np.max(vector)*0.5 + np.min(vector)*0.5

# %% [markdown]
# *Câu 12*

# %%
# Tính giá trị lớn nhất và nhỏ nhất cho các kênh màu
max_rgb = np.max(img, axis=2)
min_rgb = np.min(img, axis=2)

# Tính giá trị trung bình của giá trị lớn nhất và nhỏ nhất cho mỗi pixel
gray_img_01 = max_rgb/2 + min_rgb/2

# Tính độ sáng trung bình của ảnh
lightness = np.mean(gray_img_01)

# Hiển thị ảnh xám và giá trị độ sáng
plt.imshow(gray_img_01, cmap='gray')
plt.title(f'Lightness: {lightness:.2f}')
plt.show()

# Kiểm tra giá trị độ sáng tại điểm (0, 0)
print("Giá trị độ sáng tại (0, 0):", gray_img_01[0, 0])
# Out:
# Giá trị độ sáng tại (0, 0): 102.5

# %% [markdown]
# *Câu 13*

# %%
# Chuyển ảnh sang ảnh xám bằng phương pháp Average
gray_img_02 = np.mean(img, axis=2)

# Tính độ sáng trung bình của ảnh
lightness = np.mean(gray_img_02)

# Hiển thị ảnh xám và giá trị độ sáng
plt.imshow(gray_img_02, cmap='gray')
plt.title(f'Lightness: {lightness:.2f}')
plt.show()

# Kiểm tra giá trị độ sáng tại điểm (0, 0)
print("Giá trị độ sáng tại (0, 0):", gray_img_02[0, 0])
# Out:
# Giá trị độ sáng tại (0, 0): 107.66666666666667

# %% [markdown]
# *Câu 14*

# %%
# Chuyển ảnh sang ảnh xám bằng phương pháp Luminosity
gray_img_03 = 0.21 * img[:, :, 0] + 0.72 * img[:, :, 1] + 0.07 * img[:, :, 2]

# Tính độ sáng trung bình của ảnh
lightness = np.mean(gray_img_03)

# Hiển thị ảnh xám và giá trị độ sáng
plt.imshow(gray_img_03, cmap='gray')
plt.title(f'Lightness: {lightness:.2f}')
plt.show()

# Kiểm tra giá trị độ sáng tại điểm (0, 0)
print("Giá trị độ sáng tại (0, 0):", gray_img_03[0, 0])
# Out:
# Giá trị độ sáng tại (0, 0): 126.22999999999999
